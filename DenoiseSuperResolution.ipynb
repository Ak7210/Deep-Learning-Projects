# %%
# !pip install torcheval
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torcheval) (4.12.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 4.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import save_image
# from ignite.metrics import PSNR
from torcheval.metrics import PeakSignalNoiseRatio
import torch.nn.functional as F

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image

# %%
# ignoring the warning messages
import warnings
from IPython.display import display
warnings.filterwarnings('ignore')

# %%
class TrainDataset(Dataset):
    def __init__(self, image_path, gt_path, transform = None):
        self.image_path = image_path
        self.gt_path = gt_path
        self.transform = transform
        self.image_list = os.listdir(image_path)

    def __len__(self):
        return len(self.image_list)
    
    def __getitem__(self, idx):

        img_name = self.image_list[idx]
        img, number = img_name.split('_')
        val_img = f'gt_{number}'

        noise_img = Image.open(os.path.join(self.image_path, img_name)).convert('RGB')

        gt_img = Image.open(os.path.join(self.gt_path, val_img)).convert('RGB')

        if self.transform:
            noise_img = self.transform(noise_img)
            gt_img = self.transform(gt_img)

        return noise_img, gt_img

# %%
class TestDataset(Dataset):
    def __init__(self, image_path, transform = None):
        self.image_path = image_path
        self.transform = transform
        self.image_list = os.listdir(image_path)

    def __len__(self):
        return len(self.image_list)
    
    def __getitem__(self, idx):

        img_name = self.image_list[idx]

        noise_img = Image.open(os.path.join(self.image_path, img_name))

        if self.transform:
            noise_img = self.transform(noise_img)

        return noise_img, img_name

# %%
noise_img_transform = transforms.Compose([
    # transforms.Resize((256, 256)),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
noise_train_path = r'/kaggle/input/enhance-the-dark-world/archive/train/train'
gt_train_path = r'/kaggle/input/enhance-the-dark-world/archive/train/gt'

noise_val_path = r'/kaggle/input/enhance-the-dark-world/archive/val/val'
gt_val_path = r'/kaggle/input/enhance-the-dark-world/archive/val/gt'

noise_test_path = r'/kaggle/input/enhance-the-dark-world/archive/test'

# %%
batch_size = 16

# %%
train_dataset = TrainDataset(noise_train_path, gt_train_path, transform = noise_img_transform)

val_dataset = TrainDataset(noise_val_path, gt_val_path, transform = noise_img_transform)

test_dataset = TestDataset(noise_test_path, transform = noise_img_transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
class Conv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, activation=True):
        super(Conv2dBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.norm = nn.BatchNorm2d(out_channels)
        self.activation = activation

    def forward(self, x):
        x = self.conv(x)
        x = self.norm(x)
        if self.activation:
            x = F.leaky_relu(x, 0.2)
        return x

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            Conv2dBlock(in_channels, in_channels),
            Conv2dBlock(in_channels, in_channels, activation=False)
        )

    def forward(self, x):
        return x + self.block(x)

# %%
class AttentionBlock(nn.Module):
    def __init__(self, in_channels):
        super(AttentionBlock, self).__init__()
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, in_channels // 16, 1, padding=0),
            nn.ReLU(),
            nn.Conv2d(in_channels // 16, in_channels, 1, padding=0),
            nn.Sigmoid()
        )

    def forward(self, x):
        attention = self.channel_attention(x)
        return x * attention

# %%
class UpsampleBlock(nn.Module):
    def __init__(self, in_channels, out_channels, scale_factor=2):
        super(UpsampleBlock, self).__init__()
        self.upsample = nn.Upsample(scale_factor=scale_factor, mode='bilinear', align_corners=False)
        self.conv = Conv2dBlock(in_channels, out_channels)

    def forward(self, x):
        x = self.upsample(x)
        x = self.conv(x)
        return x

# %%
class DenoiseSuperResNet(nn.Module):
    def __init__(self):
        super(DenoiseSuperResNet, self).__init__()
        self.initial = Conv2dBlock(3, 64)

        # Encoder
        self.enc1 = Conv2dBlock(64, 128, stride=2)
        self.enc2 = Conv2dBlock(128, 256, stride=2)
        self.enc3 = Conv2dBlock(256, 512, stride=2)

        # Bottleneck
        self.bottleneck = nn.Sequential(
            *[ResidualBlock(512) for _ in range(4)],
            AttentionBlock(512)
        )

        # Decoder
        self.dec3 = UpsampleBlock(512, 256)
        self.dec2 = UpsampleBlock(256, 128)
        self.dec1 = UpsampleBlock(128, 64)

        # Residual refinement
        self.residual = nn.Sequential(*[ResidualBlock(64) for _ in range(4)])

        # Final upsampling
        self.upsample1 = UpsampleBlock(64, 64, scale_factor=2)
        self.upsample2 = UpsampleBlock(64, 64, scale_factor=2)

        # Output layer
        self.output = nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        # Initial feature extraction
        x = self.initial(x)

        # Encoder
        enc1 = self.enc1(x)
        enc2 = self.enc2(enc1)
        enc3 = self.enc3(enc2)

        # Bottleneck
        x = self.bottleneck(enc3)

        # Decoder with skip connections
        x = self.dec3(x + enc3)
        x = self.dec2(x + enc2)
        x = self.dec1(x + enc1)

        # Residual refinement and upsampling
        x = self.residual(x)
        x = self.upsample1(x)
        x = self.upsample2(x)

        # Output
        return self.output(x)

# %%
def training(model, criterion, psnr_metric, optimizer, train_loader, epoch, epochs, device, scheduler = None):

    model.train()
    running_loss = 0.0
    psnr_metric.reset()

    with tqdm(total = len(train_loader), desc=f'Epoch {epoch+1}/{epochs}', unit='batch') as tepoch:
        for noise_imgs, gt_imgs in train_loader:
            noise_imgs, gt_imgs = noise_imgs.to(device), gt_imgs.to(device)

            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                
                outputs = model(noise_imgs)
                loss = criterion(outputs, gt_imgs)
            
            scaler.scale(loss).backward()

            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            # running_loss += total_loss.item()
            psnr_value = psnr_metric.update(outputs, gt_imgs)
            psnr_ = psnr_value.compute().item()

            tepoch.set_postfix({'Training MSE': running_loss / len(train_loader), 'Training PSNR':psnr_})
            tepoch.update(1)
        if scheduler:
            scheduler.step()

    return running_loss/len(train_loader)

# %%
def validation(model, criterion,psnr_metric, val_loader, epoch, epochs, device):

    model.eval()
    running_loss = 0.0
    psnr_metric.reset()

    with torch.no_grad():
        with tqdm(total=len(val_loader), desc=f'Epoch {epoch + 1}/{epochs}', unit='batch') as tepoch:

            for noise_imgs, gt_imgs in val_loader:
                noise_imgs, gt_imgs = noise_imgs.to(device), gt_imgs.to(device)

                # Forward pass
                outputs = model(noise_imgs)
                loss = criterion(outputs, gt_imgs)


                running_loss += loss.item()
                # running_loss += total_loss.item()
                psnr_value = psnr_metric.update(outputs, gt_imgs)
                psnr_ = psnr_value.compute().item()

                tepoch.set_postfix({'Validation MSE': running_loss / len(val_loader), 'Validation PSNR': psnr_})
                tepoch.update(1)

                

    return running_loss / len(val_loader)

# %%
def train_model(model, criterion,psnr_metric, optimizer, train_loader, val_loader, num_epochs, device, scheduler = None):

    best_val_loss = float('inf')

    for epoch in range(num_epochs):

        train_loss = training(model, criterion,psnr_metric, optimizer, train_loader, epoch, num_epochs, device, scheduler)

        val_loss = validation(model, criterion, psnr_metric, val_loader, epoch, num_epochs, device)
        # scheduler.step(val_loss)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), f'best_model_{epoch+1}.pth')
            print(f'Model is saved saved with the MSE Loss {best_val_loss}')
            
        # psnr_metric.reset()

        torch.cuda.empty_cache()
            
    return model

# %%
model = DenoiseSuperResNet()

# %%
# shift the model to the GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = nn.DataParallel(model)  # Use GPUs 0 and 1
model = model.to(device)

# %%
model.load_state_dict(torch.load('/kaggle/input/13_6983_model_37_new/pytorch/default/1/best_model_37.pth'))
# Out:
# <All keys matched successfully>

# %%
num_epochs = 150
criterion = nn.MSELoss()
psnr_metric = PeakSignalNoiseRatio().to(device) 
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, weight_decay=1e-7)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.3, verbose=True)
scaler = torch.cuda.amp.GradScaler()

# %%
model = train_model(model, criterion,psnr_metric, optimizer, train_loader, val_loader, num_epochs, device)
# Out:
# Epoch 1/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 1/150: 100%|██████████| 17/17 [00:08<00:00,  2.04batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Model is saved saved with the MSE Loss 0.0001381081379162531
# Epoch 2/150: 100%|██████████| 70/70 [00:45<00:00,  1.54batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 2/150: 100%|██████████| 17/17 [00:08<00:00,  2.02batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 3/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 3/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Model is saved saved with the MSE Loss 0.00013763166241594315
# Epoch 4/150: 100%|██████████| 70/70 [00:46<00:00,  1.50batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 4/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Model is saved saved with the MSE Loss 0.00013725902553072527
# Epoch 5/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 5/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 6/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 6/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 7/150: 100%|██████████| 70/70 [00:46<00:00,  1.49batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 7/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 8/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 8/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 9/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 9/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 10/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 10/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 11/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 11/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 12/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 12/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 13/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000235, Training PSNR=30.4]
# Epoch 13/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 14/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 14/150: 100%|██████████| 17/17 [00:08<00:00,  2.00batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 15/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 15/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 16/150: 100%|██████████| 70/70 [00:46<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 16/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 17/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 17/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 18/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 18/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 19/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 19/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 20/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 20/150: 100%|██████████| 17/17 [00:08<00:00,  1.89batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 21/150: 100%|██████████| 70/70 [00:46<00:00,  1.49batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 21/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 22/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 22/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 23/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 23/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 24/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 24/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 25/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 25/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 26/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 26/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 27/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 27/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 28/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 28/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 29/150: 100%|██████████| 70/70 [00:47<00:00,  1.49batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 29/150: 100%|██████████| 17/17 [00:08<00:00,  1.94batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 30/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 30/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 31/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 31/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Model is saved saved with the MSE Loss 0.00013707471054444527
# Epoch 32/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 32/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 33/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 33/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 34/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 34/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 35/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 35/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 36/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 36/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 37/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 37/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 38/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 38/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 39/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 39/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 40/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 40/150: 100%|██████████| 17/17 [00:09<00:00,  1.88batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 41/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 41/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 42/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 42/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 43/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 43/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 44/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 44/150: 100%|██████████| 17/17 [00:09<00:00,  1.89batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 45/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 45/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 46/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 46/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 47/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 47/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 48/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 48/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 49/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 49/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 50/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 50/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 51/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 51/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Model is saved saved with the MSE Loss 0.00013680455509422566
# Epoch 52/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 52/150: 100%|██████████| 17/17 [00:08<00:00,  2.00batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 53/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 53/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 54/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 54/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 55/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 55/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 56/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000235, Training PSNR=30.4]
# Epoch 56/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000141, Validation PSNR=28]
# Epoch 57/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 57/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 58/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 58/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 59/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 59/150: 100%|██████████| 17/17 [00:08<00:00,  2.00batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 60/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 60/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 61/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 61/150: 100%|██████████| 17/17 [00:09<00:00,  1.89batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 62/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 62/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 63/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 63/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 64/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 64/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 65/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 65/150: 100%|██████████| 17/17 [00:08<00:00,  1.91batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 66/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 66/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 67/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 67/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 68/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 68/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 69/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 69/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 70/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 70/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 71/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 71/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 72/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 72/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 73/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 73/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 74/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 74/150: 100%|██████████| 17/17 [00:08<00:00,  1.94batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 75/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 75/150: 100%|██████████| 17/17 [00:08<00:00,  2.00batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 76/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 76/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 77/150: 100%|██████████| 70/70 [00:47<00:00,  1.48batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 77/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 78/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 78/150: 100%|██████████| 17/17 [00:09<00:00,  1.88batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 79/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 79/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 80/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 80/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 81/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 81/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 82/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 82/150: 100%|██████████| 17/17 [00:09<00:00,  1.84batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 83/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 83/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 84/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 84/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000141, Validation PSNR=28]
# Epoch 85/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 85/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 86/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 86/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 87/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 87/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 88/150: 100%|██████████| 70/70 [00:48<00:00,  1.44batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 88/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 89/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 89/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 90/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 90/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 91/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 91/150: 100%|██████████| 17/17 [00:08<00:00,  1.91batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 92/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 92/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 93/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 93/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 94/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 94/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 95/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 95/150: 100%|██████████| 17/17 [00:08<00:00,  1.99batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 96/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 96/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 97/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 97/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 98/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 98/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 99/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 99/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 100/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 100/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 101/150: 100%|██████████| 70/70 [00:47<00:00,  1.47batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 101/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 102/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 102/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 103/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000228, Training PSNR=30.4]
# Epoch 103/150: 100%|██████████| 17/17 [00:08<00:00,  1.94batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 104/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 104/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 105/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 105/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 106/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 106/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 107/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 107/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 108/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 108/150: 100%|██████████| 17/17 [00:08<00:00,  1.90batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 109/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 109/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 110/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 110/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 111/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 111/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 112/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 112/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 113/150: 100%|██████████| 70/70 [00:48<00:00,  1.44batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 113/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 114/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 114/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 115/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 115/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 116/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 116/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 117/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 117/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 118/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 118/150: 100%|██████████| 17/17 [00:08<00:00,  1.90batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 119/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 119/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 120/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 120/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 121/150: 100%|██████████| 70/70 [00:48<00:00,  1.44batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 121/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 122/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 122/150: 100%|██████████| 17/17 [00:08<00:00,  1.94batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 123/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 123/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 124/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 124/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 125/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 125/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 126/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 126/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 127/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 127/150: 100%|██████████| 17/17 [00:08<00:00,  1.90batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 128/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 128/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 129/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 129/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 130/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 130/150: 100%|██████████| 17/17 [00:08<00:00,  1.93batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 131/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 131/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 132/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 132/150: 100%|██████████| 17/17 [00:08<00:00,  1.94batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 133/150: 100%|██████████| 70/70 [00:49<00:00,  1.43batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 133/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 134/150: 100%|██████████| 70/70 [00:48<00:00,  1.43batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 134/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 135/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.000233, Training PSNR=30.4]
# Epoch 135/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 136/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 136/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 137/150: 100%|██████████| 70/70 [00:48<00:00,  1.46batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 137/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 138/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 138/150: 100%|██████████| 17/17 [00:08<00:00,  1.95batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 139/150: 100%|██████████| 70/70 [00:48<00:00,  1.44batch/s, Training MSE=0.000228, Training PSNR=30.4]
# Epoch 139/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000137, Validation PSNR=28.1]
# Epoch 140/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 140/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 141/150: 100%|██████████| 70/70 [00:48<00:00,  1.43batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 141/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 142/150: 100%|██████████| 70/70 [00:47<00:00,  1.46batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 142/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 143/150: 100%|██████████| 70/70 [00:48<00:00,  1.44batch/s, Training MSE=0.000234, Training PSNR=30.4]
# Epoch 143/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.00014, Validation PSNR=28]
# Epoch 144/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000229, Training PSNR=30.4]
# Epoch 144/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 145/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 145/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 146/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 146/150: 100%|██████████| 17/17 [00:08<00:00,  1.92batch/s, Validation MSE=0.000138, Validation PSNR=28.1]
# Epoch 147/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000232, Training PSNR=30.4]
# Epoch 147/150: 100%|██████████| 17/17 [00:08<00:00,  1.96batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 148/150: 100%|██████████| 70/70 [00:48<00:00,  1.43batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 148/150: 100%|██████████| 17/17 [00:08<00:00,  1.97batch/s, Validation MSE=0.000139, Validation PSNR=28]
# Epoch 149/150: 100%|██████████| 70/70 [00:48<00:00,  1.43batch/s, Training MSE=0.00023, Training PSNR=30.4]
# Epoch 149/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000139, Validation PSNR=28.1]
# Epoch 150/150: 100%|██████████| 70/70 [00:48<00:00,  1.45batch/s, Training MSE=0.000231, Training PSNR=30.4]
# Epoch 150/150: 100%|██████████| 17/17 [00:08<00:00,  1.98batch/s, Validation MSE=0.000138, Validation PSNR=28.1]

# %%
def test_prediction(model, test_loader, device, path):
    model.eval()
    with torch.no_grad():
        with tqdm(total = len(test_loader), desc = 'Testing', unit = 'batch') as tepoch:
            for noise_imgs, img_name in test_loader:
                noise_imgs = noise_imgs.to(device)

                outputs = model(noise_imgs)

                for idx in range(outputs.shape[0]):
                    # Scale the output tensor to [0, 1]
                    predicted_img = outputs[idx].squeeze(0).cpu()
                    out_path = os.path.join(path, f"{img_name[idx]}")
                    save_image(predicted_img, out_path)

                tepoch.update(1)

# %%
model.load_state_dict(torch.load('/kaggle/working/best_model_51.pth'))
# Out:
# <All keys matched successfully>

# %%
os.makedirs('/kaggle/working/outputs/predicted_images', exist_ok=True)
path = '/kaggle/working/outputs/predicted_images/'

# %%
test_prediction(model, test_loader, device, path)
# Out:
# Testing: 100%|██████████| 4/4 [00:14<00:00,  3.65s/batch]

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

def images_to_csv(folder_path, output_csv):
    data_rows = []
    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path).convert('L') 
            image_array = np.array(image).flatten()[::8]
            # Replace 'test_' with 'gt_' in the ID
            image_id = filename.split('.')[0].replace('test_', 'gt_')
            data_rows.append([image_id, *image_array])
    column_names = ['ID'] + [f'pixel_{i}' for i in range(len(data_rows[0]) - 1)]
    df = pd.DataFrame(data_rows, columns=column_names)
    df.to_csv(output_csv, index=False)
    print(f'Successfully saved to {output_csv}')

folder_path = '/kaggle/working/outputs/predicted_images'
output_csv = 'submission_202_last_model.csv'
images_to_csv(folder_path, output_csv)
# Out:
# Successfully saved to submission_202_last_model.csv
